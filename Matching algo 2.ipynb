# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
import cv2
from sklearn.metrics.pairwise import cosine_similarity
from matplotlib import colors
import colorsys
import json
import re
import tensorflow as tf
from tensorflow.keras import Model, Sequential
from tensorflow.keras.layers import Input, Conv2D, MaxPool2D , Flatten, UpSampling2D , Dense, concatenate
import pickle
import keras
from sklearn.model_selection import train_test_split
from itertools import cycle

# %%
#open training data file
with open('polyvore/train_no_dup.json') as json_file:
    train_data = json.load(json_file)

#open testing data file
with open('polyvore/test_no_dup.json') as json_file:
    test_data = json.load(json_file)

#open validation data file
with open('polyvore/valid_no_dup.json') as json_file:
    validation_data = json.load(json_file)

# %% [markdown]
# # Combine all the Test , Train and Validation data

# %%
combined_data = train_data + test_data + validation_data

# %%
df_combined = pd.DataFrame(combined_data)
df_combined.head()
# Out:
#                                                 name  views  \
# 0                                             Casual   8743
# 1  Being a Vans shoe model with Luke. Idk about t...    188
# 2                These Chanel bags is a bad habit .x    562
# 3                           Avenger/Supernatural prp   2613
# 4                                          Boho (39)     62
#
#                                                items  \
# 0  [{'index': 1, 'name': 'mock neck embroidery su...
# 1  [{'index': 1, 'name': 'nirvana distressed t-sh...
# 2  [{'index': 1, 'name': 'monki singlet', 'price'...
# 3  [{'index': 1, 'name': 'tops', 'price': 18.0, '...
# 4  [{'index': 1, 'name': 'yoins leather sexy v-ne...
#
#                                                image  likes       date  \
# 0  http://ak1.polyvoreimg.com/cgi/img-set/cid/214...    394  One month
# 1  http://ak1.polyvoreimg.com/cgi/img-set/cid/120...      9  Two years
# 2  http://ak1.polyvoreimg.com/cgi/img-set/cid/143...     32  Two years
# 3  http://ak2.polyvoreimg.com/cgi/img-set/cid/186...     88   One year
# 4  http://ak2.polyvoreimg.com/cgi/img-set/cid/206...      3   5 months
#
#                                              set_url     set_id  \
# 0    http://www.polyvore.com/casual/set?id=214181831  214181831
# 1  http://www.polyvore.com/being_vans_shoe_model_...  120161271
# 2  http://www.polyvore.com/these_chanel_bags_is_b...  143656996
# 3  http://www.polyvore.com/avenger_supernatural_p...  186627934
# 4   http://www.polyvore.com/boho_39/set?id=206969379  206969379
#
#                                                 desc
# 0  A fashion look from January 2017 by beebeely-l...
# 1  A fashion look from April 2014 featuring destr...
# 2                                           12.19.14
# 3  A fashion look from January 2016 by alyssaclai...
# 4  A fashion look from August 2016 by kate-goida ...

# %%
df_combined.columns
# Out:
# Index(['name', 'views', 'items', 'image', 'likes', 'date', 'set_url', 'set_id',
#        'desc'],
#       dtype='object')

# %%
df_combined.shape
# Out:
# (21889, 9)

# %% [markdown]
# # Use the outfit to extract only the images that match articles of clothing in our definition of an "outfit."

# %%
# define all the clothes super category - FEATURES
dress = [3,4,5,6,15, 243, 244]
bottom = [7,8,9,10, 27,28,29, 237, 238, 239, 240, 241, 332]
top = [11,17,21, 104]
pullover = [19, 4495, 4496]
outerwear = [23,24,25,236, 18]
bag = [35, 36,37, 38]
shoe = [41, 42, 43,46,47,48,49,50, 261, 262, 263, 264, 265]

# %%
# Dress, Outerwear, Shoes, Bag
type_1_category_ids = {3,4,5,6,15, 243, 244, 23,24,25, 236,35, 36,37, 38, 41, 42, 43,46,47,48,49,50, 261, 262, 263, 264, 265}   
# Top, Bottom, Pullover, Outerwear, Shoes, Bag
type_2_category_ids = {11,17,21, 104,7,8,9,10, 27,28,29, 237, 238, 239, 240, 241, 332, 18,19, 4495, 4496, 23,24,25, 236,35, 36,37, 38, 41, 42, 43,46,47,48,49,50, 261, 262, 263, 264, 265}

# %%
# Define the optional category IDs for each outfit type
type_1_optional_category_ids = {23,24,25, 236, 18}  # Outerwear (optional)
type_2_optional_category_ids = {23,24,25, 236,18,19, 4495, 4496 }  # Pullover, Outerwear (optional)

# %% [markdown]
# #Filter and keep only the outfits that match the defined types
# df_filtered = df_combined[
#     (
#         (df_combined['items'].apply(lambda x: any(item['categoryid'] in type_1_category_ids for item in x))) &
#         (
#             (df_combined['items'].apply(lambda x: set([item['categoryid'] for item in x]) & type_1_optional_category_ids == type_1_optional_category_ids)) |
#             (~df_combined['items'].apply(lambda x: any(item['categoryid'] in type_1_optional_category_ids for item in x)))
#         )
#     ) |
#     (
#         (df_combined['items'].apply(lambda x: any(item['categoryid'] in type_2_category_ids for item in x))) &
#         (
#             (df_combined['items'].apply(lambda x: set([item['categoryid'] for item in x]) & type_2_optional_category_ids == type_2_optional_category_ids)) |
#             (~df_combined['items'].apply(lambda x: any(item['categoryid'] in type_2_optional_category_ids for item in x)))
#         )
#     )
# ]

# %%
df_filtered = pd.DataFrame()
for index, row in df_combined.iterrows():
    outfit_first = [0,0,0,0]
    outfit_sec = [0,0,0,0,0,0]
    for item in row['items']:
        if item['categoryid'] in dress:
            outfit_first[0] = 1
        if item['categoryid'] in outerwear:
            outfit_first[1] = 1
            outfit_sec[3] = 1
        if item['categoryid'] in shoe:
            outfit_first[2] = 1
            outfit_sec[4] = 1
        if item['categoryid'] in bag:
            outfit_first[3] = 1
            outfit_sec[5] = 1
        if item['categoryid'] in top:
            outfit_sec[0] = 1
        if item['categoryid'] in bottom:
            outfit_sec[1] = 1
        if item['categoryid'] in pullover:
            outfit_sec[2] = 1
    if outfit_first[0] == 1 and  outfit_first[2] == 1 and outfit_first[3] == 1:
        df_filtered = df_filtered.append(row)
    if outfit_sec[0] == 1 and  outfit_sec[1] == 1 and outfit_sec[4] == 1 and outfit_sec[5] == 1:
        df_filtered = df_filtered.append(row)

# %%
# Reset the index of the filtered DataFrame
df_filtered.reset_index(drop=True, inplace=True)
df_filtered.shape
# Out:
# (7186, 9)

# %%
def get_category_id(categoryid):
    if categoryid in dress:
        return "Dress"
    if categoryid in top:
        return "Top"
    if categoryid in bottom:
        return "Bottom"
    if categoryid in pullover:
        return "Pullover"
    if categoryid in outerwear:
        return "Outerwear"
    if categoryid in shoe:
        return "Shoe"
    if categoryid in bag:
        return "Bag"

# %%
# The base URL or directory path where the images are stored
base_image_path = "polyvore-images/images/"

# Function to generate the image path based on set_id and index
def generate_image_path(row):
    set_id = row['set_id']
    image_paths = []
    for item in row['items']:
        index = item['index']
        # enter the clothing type
        item['category_name'] = get_category_id(item['categoryid'])
        image_path = f"{base_image_path}{set_id}/{index}.jpg"  # Adjust the file extension if necessary
        item['image'] = image_path
        image_paths.append(image_path)
    return image_paths


# Create a new column 'image_path' containing the generated image paths
df_filtered['image_path'] = df_filtered.apply(generate_image_path, axis=1)

# %%
df_filtered.head()
# Out:
#         date                                               desc  \
# 0  Two years                                           12.19.14
# 1   7 months  A fashion look from June 2016 by sara-86 featu...
# 2  One month  A fashion look from December 2016 by beebeely-...
# 3  Two years  A fashion look from April 2014 featuring loose...
# 4   9 months  A fashion look from April 2016 by zabead featu...
#
#                                                image  \
# 0  http://ak1.polyvoreimg.com/cgi/img-set/cid/143...
# 1  http://ak1.polyvoreimg.com/cgi/img-set/cid/201...
# 2  http://ak2.polyvoreimg.com/cgi/img-set/cid/213...
# 3  http://ak1.polyvoreimg.com/cgi/img-set/cid/118...
# 4  http://ak2.polyvoreimg.com/cgi/img-set/cid/196...
#
#                                                items   likes  \
# 0  [{'index': 1, 'name': 'monki singlet', 'price'...    32.0
# 1  [{'index': 1, 'name': 'new look light blue den...    83.0
# 2  [{'index': 1, 'name': 'yoins plus size blue st...   492.0
# 3  [{'index': 1, 'name': 'official runway web sto...  3979.0
# 4  [{'index': 1, 'name': 'burberry floral jacquar...   287.0
#
#                                   name     set_id  \
# 0  These Chanel bags is a bad habit .x  143656996
# 1                       Denim on Denim  201969694
# 2          Yoins Casual: Faux Fur Vest  213824660
# 3                           9. Lovebug  118117317
# 4                      Edgy urbanology  196794889
#
#                                              set_url    views  \
# 0  http://www.polyvore.com/these_chanel_bags_is_b...    562.0
# 1  http://www.polyvore.com/denim_on/set?id=201969694    276.0
# 2  http://www.polyvore.com/yoins_casual_faux_fur_...  24915.0
# 3   http://www.polyvore.com/lovebug/set?id=118117317  55501.0
# 4  http://www.polyvore.com/edgy_urbanology/set?id...   1005.0
#
#                                           image_path
# 0  [polyvore-images/images/143656996/1.jpg, polyv...
# 1  [polyvore-images/images/201969694/1.jpg, polyv...
# 2  [polyvore-images/images/213824660/1.jpg, polyv...
# 3  [polyvore-images/images/118117317/1.jpg, polyv...
# 4  [polyvore-images/images/196794889/1.jpg, polyv...

# %% [markdown]
# # Train an autoencoder model for each type of clothing in our defined “outfit.”

# %%
#Create dataset for each clothing item
datasets = {}

for category, categoryid in {'Bag': bag, 'Shoe': shoe, 'Dress': dress, 'Bottom': bottom, 'Top': top, 'Pullover': pullover, 'Outerwear': outerwear}.items():
    category_dataset = []
    for index, row in df_filtered.iterrows():
        items = [item for item in row['items'] if item['categoryid'] in categoryid]
        if items:
            row_data = row.copy()
            row_data['items'] = items
            #row_data['image_path'] = [path for path in row_data['image_path'] if category in path]
            selected_paths = []
            for item in items:
                selected_paths.extend([path for path in row['image_path'] if path.endswith(f"{item['index']}.jpg")])
            row_data['image_path'] = selected_paths
            category_dataset.append(row_data)
    datasets[category] = pd.DataFrame(category_dataset)

# %%
# Accessing the dataset for a specific category
pullover_data = datasets['Pullover']
outerwear_data = datasets['Outerwear']
dress_data = datasets['Dress']
bottom_data = datasets['Bottom']
top_data = datasets['Top']
bag_data = datasets['Bag']
shoe_data = datasets['Shoe']

# %%
print(pullover_data.shape)
print(outerwear_data.shape)
print(dress_data.shape)
print(bottom_data.shape)
print(top_data.shape)
print(bag_data.shape)
print(shoe_data.shape)
# Out:
# (140, 10)
# (2680, 10)
# (3239, 10)
# (4105, 10)
# (4057, 10)
# (7186, 10)
# (7186, 10)

# %%
dress_data.head()
# Out:
#          date                                               desc  \
# 3   Two years  A fashion look from April 2014 featuring loose...
# 4    9 months  A fashion look from April 2016 by zabead featu...
# 5   10 months  A fashion look from March 2016 by mari-yasuda-...
# 7     29 days  A fashion look from January 2017 by pokadoll f...
# 9  Two months  A fashion look from December 2016 by stranjaki...
#
#                                                image  \
# 3  http://ak1.polyvoreimg.com/cgi/img-set/cid/118...
# 4  http://ak2.polyvoreimg.com/cgi/img-set/cid/196...
# 5  http://ak2.polyvoreimg.com/cgi/img-set/cid/194...
# 7  http://ak1.polyvoreimg.com/cgi/img-set/cid/215...
# 9  http://ak2.polyvoreimg.com/cgi/img-set/cid/212...
#
#                                                items   likes  \
# 3  [{'index': 1, 'name': 'official runway web sto...  3979.0
# 4  [{'index': 1, 'name': 'burberry floral jacquar...   287.0
# 5  [{'index': 1, 'name': 'michael kors sleeveless...    11.0
# 7  [{'index': 1, 'name': 'sexy off-the-shoulder h...   328.0
# 9  [{'index': 1, 'name': 'balmain lace-up suede m...   977.0
#
#                        name     set_id  \
# 3                9. Lovebug  118117317
# 4           Edgy urbanology  196794889
# 5  It's a Lacey kind of day  194797482
# 7                Edgy Style  215293689
# 9                     dress  212866780
#
#                                              set_url    views  \
# 3   http://www.polyvore.com/lovebug/set?id=118117317  55501.0
# 4  http://www.polyvore.com/edgy_urbanology/set?id...   1005.0
# 5  http://www.polyvore.com/its_lacey_kind_day/set...    139.0
# 7  http://www.polyvore.com/edgy_style/set?id=2152...   1218.0
# 9     http://www.polyvore.com/dress/set?id=212866780   2939.0
#
#                                  image_path
# 3  [polyvore-images/images/118117317/1.jpg]
# 4  [polyvore-images/images/196794889/1.jpg]
# 5  [polyvore-images/images/194797482/1.jpg]
# 7  [polyvore-images/images/215293689/1.jpg]
# 9  [polyvore-images/images/212866780/1.jpg]

# %%
# reading .jpg images to bytes - OpenCV allows you to read images as bytes in Python
def prepare_images(fpath):
    image = cv2.imread(fpath, cv2.IMREAD_COLOR)
    #plt.imshow(image)
    #plt.show() 
    image = cv2.resize(image, (32,32))
    image = image / 255.0
    return image

# %%
def get_data(data_path, dataframe):
    cleanedList = [x for x in data_path if str(x) != 'nan']
    output = []
    for path in cleanedList:
        if path == 'nan':
            continue 
        else:
            file_path = os.path.normpath(path[0])
            output.append(prepare_images(file_path))
    return np.array(output)

# %%
clothing_list = ['Top', 'Bottom', 'Dress', 'Pullover', 'Outerwear', 'Shoe', 'Bag']

# %%
autoencoder_models = {}
encoder_file_path = "model/encoder/"
model_weights_file_path = "model/weights/"

# %%
#Train an autoencoder model for each type of clothing in our defined “outfit.”


for clothing_type, dataset in datasets.items():
    features = get_data(list(dataset['image_path']), dataset)
    
    
    #encoded
    input_layer = Input(shape=(32,32,3))
    conv1 = Conv2D(496, (3,3), activation = 'relu', padding = 'same')(input_layer)
    pool1 = tf.keras.layers.MaxPooling2D(pool_size=(2,2))(conv1)
    conv2 = Conv2D(248, (3,3), activation = 'relu', padding = 'same')(pool1)
    pool2 = tf.keras.layers.MaxPooling2D(pool_size=(2,2))(conv2)
    conv3 = Conv2D(124, (3,3), activation = 'relu', padding = 'same')(pool2)
    pool3 = tf.keras.layers.MaxPooling2D(pool_size=(2,2))(conv3)
    conv4 = Conv2D(64, (3,3), activation = 'relu', padding = 'same')(pool3)
    pool4 = tf.keras.layers.MaxPooling2D(pool_size=(2,2))(conv4)
    conv5 = Conv2D(32, (3,3), activation = 'relu', padding = 'same')(pool4)
    pool5 = tf.keras.layers.MaxPooling2D(pool_size=(2,2))(conv5)
    #conv6 = Conv2D(16, (3,3), activation = 'relu', padding = 'same')(pool5)
    #pool6 = tf.keras.layers.MaxPooling2D(pool_size=(2,2))(conv6)
    #conv7 = Conv2D(16, (3,3), activation = 'relu', padding = 'same')(pool6)
    #pool7 = tf.keras.layers.MaxPooling2D(pool_size=(2,2))(conv7)
    
    encoded = Flatten(name="encoded")(pool5)
    
    #decoding
    #conv8 = Conv2D(16, (3,3), activation = 'relu', padding = 'same')(pool7)
    #pool8 = UpSampling2D((2,2))(conv8)
    #conv9 = Conv2D(16, (3,3), activation = 'relu', padding = 'same')(pool6)
    #pool9 = UpSampling2D((2,2))(conv9)
    conv10 = Conv2D(32, (3,3), activation = 'relu', padding = 'same')(pool5)
    pool10 = UpSampling2D((2,2))(conv10)
    conv11 = Conv2D(64, (3,3), activation = 'relu', padding = 'same')(pool10)
    pool11 = UpSampling2D((2,2))(conv11)
    conv12 = Conv2D(124, (3,3), activation = 'relu', padding = 'same')(pool11)
    pool12 = UpSampling2D((2,2))(conv12)
    conv13 = Conv2D(248, (3,3), activation = 'relu', padding = 'same')(pool12)
    pool13 = UpSampling2D((2,2))(conv13)
    conv14 = Conv2D(496, (3,3), activation = 'relu', padding = 'same')(pool13)
    pool14 = UpSampling2D((2,2))(conv14)
    
    decoded = Conv2D(3,1,1,activation='sigmoid',padding='same')(pool14)
    
    autoencoder = Model(input_layer, decoded)
    autoencoder.compile(optimizer="adadelta",loss='binary_crossentropy')
    encoder = Model(input_layer, encoded)
    
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience = 10, verbose = 1, mode = 'auto')
    print("Fitting " + clothing_type)
    autoencoder.fit(features, features, epochs=5, batch_size=100, validation_split=.15,callbacks=(early_stopping))
    
    encoder.save(encoder_file_path + clothing_type + "_encoder_model.h5")
    autoencoder.save(encoder_file_path + clothing_type + "_autoencoder_model.h5")
    
    autoencoder_models[clothing_type] = autoencoder
    
    weights = encoder.get_weights()
    with open(model_weights_file_path + clothing_type + "_model_weights.pkl" , 'wb') as w:
        pickle.dump(weights, w)
        
    del(autoencoder)
    del(encoder)
    tf.keras.backend.clear_session()
# Out:
# Fitting Bag
# Epoch 1/5
# 62/62 [==============================] - 285s 5s/step - loss: 0.6931 - val_loss: 0.6930
# Epoch 2/5
# 62/62 [==============================] - 259s 4s/step - loss: 0.6930 - val_loss: 0.6929
# Epoch 3/5
# 62/62 [==============================] - 319s 5s/step - loss: 0.6928 - val_loss: 0.6927
# Epoch 4/5
# 62/62 [==============================] - 309s 5s/step - loss: 0.6927 - val_loss: 0.6925
# Epoch 5/5
# 62/62 [==============================] - 298s 5s/step - loss: 0.6926 - val_loss: 0.6923
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Fitting Shoe
# Epoch 1/5
# 62/62 [==============================] - 263s 4s/step - loss: 0.6930 - val_loss: 0.6929
# Epoch 2/5
# 62/62 [==============================] - 233s 4s/step - loss: 0.6928 - val_loss: 0.6926
# Epoch 3/5
# 62/62 [==============================] - 251s 4s/step - loss: 0.6925 - val_loss: 0.6923
# Epoch 4/5
# 62/62 [==============================] - 244s 4s/step - loss: 0.6922 - val_loss: 0.6919
# Epoch 5/5
# 62/62 [==============================] - 213s 3s/step - loss: 0.6918 - val_loss: 0.6915
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Fitting Dress
# Epoch 1/5
# 28/28 [==============================] - 96s 3s/step - loss: 0.6932 - val_loss: 0.6932
# Epoch 2/5
# 28/28 [==============================] - 95s 3s/step - loss: 0.6931 - val_loss: 0.6931
# Epoch 3/5
# 28/28 [==============================] - 93s 3s/step - loss: 0.6931 - val_loss: 0.6930
# Epoch 4/5
# 28/28 [==============================] - 94s 3s/step - loss: 0.6930 - val_loss: 0.6930
# Epoch 5/5
# 28/28 [==============================] - 96s 3s/step - loss: 0.6930 - val_loss: 0.6929
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Fitting Bottom
# Epoch 1/5
# 35/35 [==============================] - 125s 4s/step - loss: 0.6931 - val_loss: 0.6931
# Epoch 2/5
# 35/35 [==============================] - 126s 4s/step - loss: 0.6931 - val_loss: 0.6931
# Epoch 3/5
# 35/35 [==============================] - 133s 4s/step - loss: 0.6931 - val_loss: 0.6930
# Epoch 4/5
# 35/35 [==============================] - 121s 3s/step - loss: 0.6930 - val_loss: 0.6929
# Epoch 5/5
# 35/35 [==============================] - 124s 4s/step - loss: 0.6930 - val_loss: 0.6929
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Fitting Top
# Epoch 1/5
# 35/35 [==============================] - 119s 3s/step - loss: 0.6933 - val_loss: 0.6932
# Epoch 2/5
# 35/35 [==============================] - 118s 3s/step - loss: 0.6932 - val_loss: 0.6931
# Epoch 3/5
# 35/35 [==============================] - 117s 3s/step - loss: 0.6930 - val_loss: 0.6930
# Epoch 4/5
# 35/35 [==============================] - 130s 4s/step - loss: 0.6929 - val_loss: 0.6928
# Epoch 5/5
# 35/35 [==============================] - 118s 3s/step - loss: 0.6928 - val_loss: 0.6927
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Fitting Pullover
# Epoch 1/5
# 2/2 [==============================] - 6s 1s/step - loss: 0.6931 - val_loss: 0.6931
# Epoch 2/5
# 2/2 [==============================] - 5s 1s/step - loss: 0.6931 - val_loss: 0.6931
# Epoch 3/5
# 2/2 [==============================] - 5s 952ms/step - loss: 0.6931 - val_loss: 0.6931
# Epoch 4/5
# 2/2 [==============================] - 4s 825ms/step - loss: 0.6931 - val_loss: 0.6931
# Epoch 5/5
# 2/2 [==============================] - 5s 1s/step - loss: 0.6931 - val_loss: 0.6931
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Fitting Outerwear
# Epoch 1/5
# 23/23 [==============================] - 84s 4s/step - loss: 0.6931 - val_loss: 0.6931
# Epoch 2/5
# 23/23 [==============================] - 82s 4s/step - loss: 0.6931 - val_loss: 0.6931
# Epoch 3/5
# 23/23 [==============================] - 82s 4s/step - loss: 0.6931 - val_loss: 0.6930
# Epoch 4/5
# 23/23 [==============================] - 81s 4s/step - loss: 0.6930 - val_loss: 0.6930
# Epoch 5/5
# 23/23 [==============================] - 83s 4s/step - loss: 0.6930 - val_loss: 0.6929
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
for clothing_type in clothing_list:
    autoencoder_models[clothing_type] = tf.keras.models.load_model(encoder_file_path + clothing_type + "_autoencoder_model.h5")

# %%
autoencoder_models
# Out:
# {'Top': <keras.engine.functional.Functional at 0x2391ca9b460>,
#  'Bottom': <keras.engine.functional.Functional at 0x2394ec026d0>,
#  'Dress': <keras.engine.functional.Functional at 0x23944cd17c0>,
#  'Pullover': <keras.engine.functional.Functional at 0x2394eac5790>,
#  'Outerwear': <keras.engine.functional.Functional at 0x2394eda0dc0>,
#  'Shoe': <keras.engine.functional.Functional at 0x2394a2196a0>,
#  'Bag': <keras.engine.functional.Functional at 0x2394f449250>}

# %% [markdown]
# # Predict embeddings for each input image.

# %%
#Predict embeddings for each input image.
def predict_embeddings(image_url, autoencoder):
    # Preprocess image
    preprocessed_image = prepare_images(image_url)
    preprocessed_image = np.expand_dims(preprocessed_image, axis=0)
    encoder = tf.keras.Model(inputs=autoencoder.input, outputs=autoencoder.get_layer('conv2d_10').output)
    embeddings = encoder.predict(preprocessed_image)
    flatten_embeddings = embeddings.flatten()
    return embeddings

# %% [markdown]
# #Combined data data
# com_data = []
# com_likes = []
#
# df_filtered['processed_image'] = None
# df_filtered['embedding_image'] = None
#
# for index, row in df_filtered.iterrows():
#     processed_images = []
#     embedding_images = []
#     for item in row['image_path']:
#         for key, value in item.items():
#             #print(key, value)
#             if key is not None:
#                 processed_image = prepare_images(value)
#                 processed_images.append(processed_image)
#                 predicted_embeddings = predict_embeddings(value, autoencoder_models[key])
#                 embedding_images.append(predicted_embeddings)
#     df_filtered.at[index, 'processed_image'] = processed_images
#     df_filtered.at[index, 'embedding_image'] = embedding_images
#     com_data.append(embedding_images)
#     com_likes.append(row['likes'])

# %% [markdown]
# print(len(com_data))
# print(len(com_likes))

# %%
for clothing_type, dataset in datasets.items():
    print(dataset.shape)
# Out:
# (7186, 10)
# (7186, 10)
# (3239, 10)
# (4105, 10)
# (4057, 10)
# (140, 10)
# (2680, 10)

# %%
embedding_file_path = "model/embeddings/"

# %%
from sklearn.decomposition import IncrementalPCA
from sklearn.decomposition import PCA


# Perform Incremental PCA on the training set
n_components = 50 
batch_size = 1000  

for clothing_type, dataset in datasets.items():
    embedding_images = []
    target_likes = []
    
    for index, row in dataset.iterrows():
        for item in row['image_path']:
            predicted_embeddings = predict_embeddings(item, autoencoder_models[clothing_type])
            embedding_images.append(predicted_embeddings)
            target_likes.append(row['likes'])

    # Reshape the embedding_images array to have 2 dimensions
    embedding_images = np.array(embedding_images, dtype=np.float32)  # Convert the list to a NumPy array
    embedding_images = np.reshape(embedding_images, (len(embedding_images), -1))  # Reshape the array
    
    print("Embedding images of " + clothing_type + " splitted into train and val data")
    embedding_images_train, embedding_images_val, likes_train, likes_val = train_test_split(embedding_images, target_likes, test_size=0.2, random_state=42)
    
    # Perform PCA on the training set
    n_components = min(embedding_images_train.shape[0], embedding_images_train.shape[1])  # Use the minimum of rows and columns as n_components

    pca = PCA(n_components=n_components)
    reduced_embeddings_train = pca.fit_transform(embedding_images_train)
    
    print("Transforming...")
    # Transform the validation set 
    reduced_embeddings_val = pca.transform(embedding_images_val)
    
    print("Saving " + clothing_type + " as a npy")
    # Save the reduced embeddings
    np.save(embedding_file_path + clothing_type + '_train_embeddings.npy', reduced_embeddings_train)
    np.save(embedding_file_path + clothing_type + '_val_embeddings.npy', reduced_embeddings_val)
    
    # Save the corresponding target likes
    np.save(embedding_file_path + clothing_type + '_train_likes.npy', likes_train)
    np.save(embedding_file_path + clothing_type + '_val_likes.npy', likes_val)
# Out:
# 1/1 [==============================] - 0s 353ms/step
# 1/1 [==============================] - 0s 208ms/step
# 1/1 [==============================] - 0s 214ms/step
# 1/1 [==============================] - 0s 188ms/step
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002395040C310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 211ms/step
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002395040CEE0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 208ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 237ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 232ms/step
# 1/1 [==============================] - 0s 216ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 219ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 210ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 210ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 219ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 206ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 209ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 252ms/step
# 1/1 [==============================] - 0s 259ms/step
# 1/1 [==============================] - 0s 260ms/step
# 1/1 [==============================] - 0s 261ms/step
# 1/1 [==============================] - 0s 251ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 209ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 225ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 210ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 248ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 225ms/step
# 1/1 [==============================] - 0s 208ms/step
# 1/1 [==============================] - 0s 225ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 252ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 206ms/step
# 1/1 [==============================] - 0s 248ms/step
# 1/1 [==============================] - 0s 224ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 229ms/step
# 1/1 [==============================] - 0s 229ms/step
# 1/1 [==============================] - 0s 313ms/step
# 1/1 [==============================] - 0s 212ms/step
# 1/1 [==============================] - 0s 261ms/step
# 1/1 [==============================] - 1s 513ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 263ms/step
# 1/1 [==============================] - 0s 280ms/step
# 1/1 [==============================] - 0s 290ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 282ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 221ms/step
# 1/1 [==============================] - 0s 208ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 376ms/step
# 1/1 [==============================] - 0s 452ms/step
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 243ms/step
# 1/1 [==============================] - 0s 329ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 210ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 284ms/step
# 1/1 [==============================] - 0s 229ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 211ms/step
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 215ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 224ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 265ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 211ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 257ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 218ms/step
# 1/1 [==============================] - 0s 207ms/step
# 1/1 [==============================] - 0s 227ms/step
# 1/1 [==============================] - 0s 249ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 302ms/step
# 1/1 [==============================] - 0s 249ms/step
# 1/1 [==============================] - 0s 231ms/step
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 225ms/step
# 1/1 [==============================] - 0s 232ms/step
# 1/1 [==============================] - 0s 248ms/step
# 1/1 [==============================] - 0s 250ms/step
# 1/1 [==============================] - 0s 232ms/step
# 1/1 [==============================] - 0s 238ms/step
# 1/1 [==============================] - 0s 210ms/step
# 1/1 [==============================] - 0s 243ms/step
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 243ms/step
# 1/1 [==============================] - 0s 209ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 210ms/step
# 1/1 [==============================] - 0s 223ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 223ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 207ms/step
# 1/1 [==============================] - 0s 230ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 225ms/step
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 212ms/step
# 1/1 [==============================] - 0s 236ms/step
# 1/1 [==============================] - 0s 232ms/step
# 1/1 [==============================] - 0s 227ms/step
# 1/1 [==============================] - 0s 207ms/step
# 1/1 [==============================] - 0s 224ms/step
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 236ms/step
# 1/1 [==============================] - 0s 258ms/step
# 1/1 [==============================] - 0s 218ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 206ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 250ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 227ms/step
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 222ms/step
# 1/1 [==============================] - 0s 229ms/step
# 1/1 [==============================] - 0s 238ms/step
# 1/1 [==============================] - 0s 212ms/step
# 1/1 [==============================] - 0s 229ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 241ms/step
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 232ms/step
# 1/1 [==============================] - 0s 208ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 216ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 208ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 215ms/step
# 1/1 [==============================] - 0s 226ms/step
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 245ms/step
# 1/1 [==============================] - 0s 206ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 240ms/step
# 1/1 [==============================] - 0s 221ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 231ms/step
# 1/1 [==============================] - 0s 256ms/step
# 1/1 [==============================] - 0s 260ms/step
# 1/1 [==============================] - 0s 253ms/step
# 1/1 [==============================] - 0s 221ms/step
# 1/1 [==============================] - 0s 225ms/step
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 245ms/step
# 1/1 [==============================] - 0s 222ms/step
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 229ms/step
# 1/1 [==============================] - 0s 219ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 239ms/step
# 1/1 [==============================] - 0s 241ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 221ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 254ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 223ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 210ms/step
# 1/1 [==============================] - 0s 225ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 226ms/step
# 1/1 [==============================] - 0s 235ms/step
# 1/1 [==============================] - 0s 231ms/step
# 1/1 [==============================] - 0s 231ms/step
# 1/1 [==============================] - 0s 211ms/step
# 1/1 [==============================] - 0s 227ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 208ms/step
# 1/1 [==============================] - 0s 240ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 236ms/step
# 1/1 [==============================] - 0s 239ms/step
# 1/1 [==============================] - 0s 209ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 228ms/step
# 1/1 [==============================] - 0s 209ms/step
# 1/1 [==============================] - 0s 216ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 246ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 239ms/step
# 1/1 [==============================] - 0s 218ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 260ms/step
# 1/1 [==============================] - 0s 245ms/step
# 1/1 [==============================] - 0s 240ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 251ms/step
# 1/1 [==============================] - 0s 238ms/step
# 1/1 [==============================] - 0s 224ms/step
# 1/1 [==============================] - 0s 259ms/step
# 1/1 [==============================] - 0s 270ms/step
# 1/1 [==============================] - 0s 219ms/step
# 1/1 [==============================] - 0s 243ms/step
# 1/1 [==============================] - 0s 230ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 214ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 218ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 209ms/step
# 1/1 [==============================] - 0s 212ms/step
# 1/1 [==============================] - 0s 214ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 310ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 437ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 282ms/step
# 1/1 [==============================] - 0s 241ms/step
# 1/1 [==============================] - 0s 256ms/step
# 1/1 [==============================] - 0s 370ms/step
# 1/1 [==============================] - 0s 341ms/step
# 1/1 [==============================] - 0s 277ms/step
# 1/1 [==============================] - 1s 504ms/step
# 1/1 [==============================] - 0s 306ms/step
# 1/1 [==============================] - 0s 259ms/step
# 1/1 [==============================] - 0s 241ms/step
# 1/1 [==============================] - 0s 445ms/step
# 1/1 [==============================] - 0s 247ms/step
# 1/1 [==============================] - 0s 218ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 206ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 354ms/step
# 1/1 [==============================] - 0s 228ms/step
# 1/1 [==============================] - 0s 300ms/step
# 1/1 [==============================] - 0s 315ms/step
# 1/1 [==============================] - 0s 252ms/step
# 1/1 [==============================] - 0s 299ms/step
# 1/1 [==============================] - 0s 282ms/step
# 1/1 [==============================] - 0s 261ms/step
# 1/1 [==============================] - 0s 345ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 335ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 302ms/step
# 1/1 [==============================] - 0s 257ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 210ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 218ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 297ms/step
# 1/1 [==============================] - 0s 263ms/step
# 1/1 [==============================] - 0s 303ms/step
# 1/1 [==============================] - 0s 224ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 209ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 219ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 282ms/step
# 1/1 [==============================] - 0s 358ms/step
# 1/1 [==============================] - 0s 292ms/step
# 1/1 [==============================] - 0s 222ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 240ms/step
# 1/1 [==============================] - 0s 216ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 249ms/step
# 1/1 [==============================] - 0s 239ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 225ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 267ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 250ms/step
# 1/1 [==============================] - 0s 337ms/step
# 1/1 [==============================] - 0s 214ms/step
# 1/1 [==============================] - 0s 224ms/step
# 1/1 [==============================] - 0s 302ms/step
# 1/1 [==============================] - 0s 288ms/step
# 1/1 [==============================] - 0s 264ms/step
# 1/1 [==============================] - 0s 241ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 222ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 219ms/step
# 1/1 [==============================] - 0s 227ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 207ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 209ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 224ms/step
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 289ms/step
# 1/1 [==============================] - 0s 464ms/step
# 1/1 [==============================] - 0s 245ms/step
# 1/1 [==============================] - 0s 253ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 322ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 214ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 210ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 208ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 208ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 212ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 209ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 243ms/step
# 1/1 [==============================] - 0s 229ms/step
# 1/1 [==============================] - 0s 250ms/step
# 1/1 [==============================] - 0s 238ms/step
# 1/1 [==============================] - 0s 241ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 212ms/step
# 1/1 [==============================] - 0s 214ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 212ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 299ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 231ms/step
# 1/1 [==============================] - 0s 260ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 216ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 211ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 230ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 211ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 238ms/step
# 1/1 [==============================] - 0s 253ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 214ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 206ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 212ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 209ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 208ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 223ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 209ms/step
# 1/1 [==============================] - 0s 206ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 248ms/step
# 1/1 [==============================] - 0s 275ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 282ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 241ms/step
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 210ms/step
# 1/1 [==============================] - 0s 245ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 218ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 171ms/step
# ...
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 218ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 221ms/step
# 1/1 [==============================] - 0s 242ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 243ms/step
# 1/1 [==============================] - 0s 227ms/step
# 1/1 [==============================] - 0s 247ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 206ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 229ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 209ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 225ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 218ms/step
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 227ms/step
# 1/1 [==============================] - 0s 215ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 211ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 221ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 196ms/step
# 1/1 [==============================] - 0s 210ms/step
# 1/1 [==============================] - 0s 185ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 198ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 236ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 210ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 208ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 207ms/step
# 1/1 [==============================] - 0s 305ms/step
# 1/1 [==============================] - 0s 299ms/step
# 1/1 [==============================] - 0s 306ms/step
# 1/1 [==============================] - 0s 250ms/step
# 1/1 [==============================] - 0s 231ms/step
# 1/1 [==============================] - 0s 403ms/step
# 1/1 [==============================] - 0s 402ms/step
# 1/1 [==============================] - 0s 281ms/step
# 1/1 [==============================] - 0s 267ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 278ms/step
# 1/1 [==============================] - 0s 208ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 220ms/step
# 1/1 [==============================] - 0s 235ms/step
# 1/1 [==============================] - 0s 254ms/step
# 1/1 [==============================] - 0s 290ms/step
# 1/1 [==============================] - 0s 253ms/step
# 1/1 [==============================] - 0s 285ms/step
# 1/1 [==============================] - 0s 261ms/step
# 1/1 [==============================] - 0s 373ms/step
# 1/1 [==============================] - 0s 392ms/step
# 1/1 [==============================] - 0s 270ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 264ms/step
# 1/1 [==============================] - 0s 355ms/step
# 1/1 [==============================] - 0s 228ms/step
# 1/1 [==============================] - 0s 263ms/step
# 1/1 [==============================] - 0s 225ms/step
# 1/1 [==============================] - 0s 222ms/step
# 1/1 [==============================] - 0s 214ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 214ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 244ms/step
# 1/1 [==============================] - 0s 249ms/step
# 1/1 [==============================] - 0s 260ms/step
# 1/1 [==============================] - 0s 219ms/step
# 1/1 [==============================] - 0s 260ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 246ms/step
# 1/1 [==============================] - 0s 251ms/step
# 1/1 [==============================] - 0s 302ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 257ms/step
# 1/1 [==============================] - 0s 189ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-6789d26b83dd> in <module>
#      13     for index, row in dataset.iterrows():
#      14         for item in row['image_path']:
# ---> 15             predicted_embeddings = predict_embeddings(item, autoencoder_models[clothing_type])
#      16             embedding_images.append(predicted_embeddings)
#      17             target_likes.append(row['likes'])
#
# <ipython-input-25-954f8f373a5d> in predict_embeddings(image_url, autoencoder)
#       5     preprocessed_image = np.expand_dims(preprocessed_image, axis=0)
#       6     encoder = tf.keras.Model(inputs=autoencoder.input, outputs=autoencoder.get_layer('conv2d_10').output)
# ----> 7     embeddings = encoder.predict(preprocessed_image)
#       8     flatten_embeddings = embeddings.flatten()
#       9     return embeddings
#
# ~\Anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2380                     for step in data_handler.steps():
#    2381                         callbacks.on_predict_batch_begin(step)
# -> 2382                         tmp_batch_outputs = self.predict_function(iterator)
#    2383                         if data_handler.should_sync:
#    2384                             context.async_wait()
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in __call__(self, *args, **kwds)
#     892
#     893       with OptionalXlaContext(self._jit_compile):
# --> 894         result = self._call(*args, **kwds)
#     895
#     896       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in _call(self, *args, **kwds)
#     964               args, kwds))
#     965       # If we did not create any variables the trace we have is good enough.
# --> 966       return self._concrete_variable_creation_fn._call_flat(   # pylint: disable=protected-access
#     967           filtered_flat_args,
#     968           self._concrete_variable_creation_fn.captured_inputs)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1755         and executing_eagerly):
#    1756       # No tape is watching; skip to running the function.
# -> 1757       return self._build_call_outputs(self._inference_function.call(
#    1758           ctx, args, cancellation_manager=cancellation_manager))
#    1759     forward_backward = self._select_forward_and_backward_functions(
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py in call(self, ctx, args, cancellation_manager)
#     379       with _InterpolateFunctionError(self):
#     380         if cancellation_manager is None:
# --> 381           outputs = execute.execute(
#     382               str(self.signature.name),
#     383               num_outputs=self._num_outputs,
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# #Accessing the dataset for a specific category
# dress_com_data = np.load(embedding_file_path + 'dress_embeddings.npy')
# top_com_data = np.load(embedding_file_path + 'top_embeddings.npy')
# bottom_com_data = np.load(embedding_file_path + 'bottom_embeddings.npy')
# pullover_com_data = np.load(embedding_file_path + 'pullover_embeddings.npy')
# outerwear_com_data = np.load(embedding_file_path + 'outerwear_embeddings.npy')
# shoe_com_data = np.load(embedding_file_path + 'shoe_embeddings.npy')
# bag_com_data = np.load(embedding_file_path + 'bag_embeddings.npy')

# %% [markdown]
# dress_data_train, top_data_train, bottom_data_train, pullover_data_train, outerwear_data_train, shoe_data_train, bag_data_train = inputs_train
# dress_data_val, top_data_val, bottom_data_val, pullover_data_val, outerwear_data_val, shoe_data_val, bag_data_val = inputs_val

# %%
dress_data_train = np.load(embedding_file_path + 'Dress_train_embeddings.npy')
top_data_train = np.load(embedding_file_path + 'Top_train_embeddings.npy')
bottom_data_train = np.load(embedding_file_path + 'Bottom_train_embeddings.npy')
pullover_data_train = np.load(embedding_file_path + 'Pullover_train_embeddings.npy')
outerwear_data_train = np.load(embedding_file_path + 'Outerwear_train_embeddings.npy')
shoe_data_train = np.load(embedding_file_path + 'Shoe_train_embeddings.npy')
bag_data_train = np.load(embedding_file_path + 'Bag_train_embeddings.npy')

print(dress_data_train.shape)
print(top_data_train.shape)
print(bottom_data_train.shape)
print(outerwear_data_train.shape)
print(pullover_data_train.shape)
print(shoe_data_train.shape)
print(bag_data_train.shape)
# Out:
# (2733, 2733)
# (3364, 3072)
# (3338, 3072)
# (2184, 2184)
# (115, 115)
# (6067, 3072)
# (5842, 128)

# %%
from skimage.transform import resize

datasets = [dress_data_train, top_data_train, bottom_data_train, outerwear_data_train, pullover_data_train, shoe_data_train, bag_data_train]

# Normalize each dataset
for i in range(len(clothing_list)):
    # Resize each dataset to (32, 32, 3)
    resized_data = np.zeros((datasets[i].shape[0], 32, 32, 3))
    for j in range(datasets[i].shape[0]):
        resized_data[j] = resize(datasets[i][j], (32, 32, 3), anti_aliasing=True)
    
    # Normalize the pixel values to [0, 1]
    normalized_data = (resized_data - np.min(resized_data)) / (np.max(resized_data) - np.min(resized_data))
    
    # Convert the data to float32
    normalized_data = normalized_data.astype(np.float32)
    
    # Update the dataset with the normalized data
    datasets[i] = normalized_data

# %%
dress_data_train = datasets[0]
top_data_train = datasets[1]
bottom_data_train = datasets[2]
pullover_data_train = datasets[3]
outerwear_data_train = datasets[4]
shoe_data_train = datasets[5]
bag_data_train = datasets[6]

print(dress_data_train.shape)
print(top_data_train.shape)
print(bottom_data_train.shape)
print(outerwear_data_train.shape)
print(pullover_data_train.shape)
print(shoe_data_train.shape)
print(bag_data_train.shape)
# Out:
# (2733, 32, 32, 3)
# (3364, 32, 32, 3)
# (3338, 32, 32, 3)
# (115, 32, 32, 3)
# (2184, 32, 32, 3)
# (6067, 32, 32, 3)
# (5842, 32, 32, 3)

# %%
dress_likes_train = np.load(embedding_file_path + 'Dress_train_likes.npy')
top_likes_train = np.load(embedding_file_path + 'Top_train_likes.npy')
bottom_likes_train = np.load(embedding_file_path + 'Bottom_train_likes.npy')
pullover_likes_train = np.load(embedding_file_path + 'Pullover_train_likes.npy')
outerwear_likes_train = np.load(embedding_file_path + 'Outerwear_train_likes.npy')
shoe_likes_train = np.load(embedding_file_path + 'Shoe_train_likes.npy')
bag_likes_train = np.load(embedding_file_path + 'Bag_train_likes.npy')

print(dress_likes_train.shape)
print(top_likes_train.shape)
print(bottom_likes_train.shape)
print(outerwear_likes_train.shape)
print(pullover_likes_train.shape)
print(shoe_likes_train.shape)
print(bag_likes_train.shape)
# Out:
# (2733,)
# (3364,)
# (3338,)
# (2184,)
# (115,)
# (6067,)
# (5842,)

# %%
all_likes_train = np.concatenate([dress_likes_train, top_likes_train, bottom_likes_train, pullover_likes_train, outerwear_likes_train, shoe_likes_train, bag_likes_train], axis=0)

# %%
dress_data_val = np.load(embedding_file_path + 'Dress_val_embeddings.npy')
top_data_val = np.load(embedding_file_path + 'Top_val_embeddings.npy')
bottom_data_val = np.load(embedding_file_path + 'Bottom_val_embeddings.npy')
pullover_data_val = np.load(embedding_file_path + 'Pullover_val_embeddings.npy')
outerwear_data_val = np.load(embedding_file_path + 'Outerwear_val_embeddings.npy')
shoe_data_val = np.load(embedding_file_path + 'Shoe_val_embeddings.npy')
bag_data_val = np.load(embedding_file_path + 'Bag_val_embeddings.npy')

print(dress_data_val.shape)
print(top_data_val.shape)
print(bottom_data_val.shape)
print(outerwear_data_val.shape)
print(pullover_data_val.shape)
print(shoe_data_val.shape)
print(bag_data_val.shape)
# Out:
# (684, 2733)
# (842, 3072)
# (835, 3072)
# (547, 2184)
# (29, 115)
# (1517, 3072)
# (1461, 128)

# %%
dataset_val = [dress_data_val, top_data_val, bottom_data_val, outerwear_data_val, pullover_data_val, shoe_data_val, bag_data_val]

# Normalize each dataset
for i in range(len(clothing_list)):
    # Resize each dataset to (32, 32, 3)
    resized_data = np.zeros((dataset_val[i].shape[0], 32, 32, 3))
    for j in range(dataset_val[i].shape[0]):
        resized_data[j] = resize(dataset_val[i][j], (32, 32, 3), anti_aliasing=True)
    
    # Normalize the pixel values to [0, 1]
    normalized_data = (resized_data - np.min(resized_data)) / (np.max(resized_data) - np.min(resized_data))
    
    # Convert the data to float32
    normalized_data = normalized_data.astype(np.float32)
    
    # Update the dataset with the normalized data
    dataset_val[i] = normalized_data

# %%
dress_data_val = dataset_val[0]
top_data_val = dataset_val[1]
bottom_data_val = dataset_val[2]
pullover_data_val = dataset_val[3]
outerwear_data_val = dataset_val[4]
shoe_data_val = dataset_val[5]
bag_data_val = dataset_val[6]

print(dress_data_val.shape)
print(top_data_val.shape)
print(bottom_data_val.shape)
print(outerwear_data_val.shape)
print(pullover_data_val.shape)
print(shoe_data_val.shape)
print(bag_data_val.shape)
# Out:
# (684, 32, 32, 3)
# (842, 32, 32, 3)
# (835, 32, 32, 3)
# (29, 32, 32, 3)
# (547, 32, 32, 3)
# (1517, 32, 32, 3)
# (1461, 32, 32, 3)

# %%
dress_likes_val = np.load(embedding_file_path + 'Dress_val_likes.npy')
top_likes_val = np.load(embedding_file_path + 'Top_val_likes.npy')
bottom_likes_val = np.load(embedding_file_path + 'Bottom_val_likes.npy')
pullover_likes_val = np.load(embedding_file_path + 'Pullover_val_likes.npy')
outerwear_likes_val = np.load(embedding_file_path + 'Outerwear_val_likes.npy')
shoe_likes_val = np.load(embedding_file_path + 'Shoe_val_likes.npy')
bag_likes_val = np.load(embedding_file_path + 'Bag_val_likes.npy')

print(dress_likes_val.shape)
print(top_likes_val.shape)
print(bottom_likes_val.shape)
print(outerwear_likes_val.shape)
print(pullover_likes_val.shape)
print(shoe_likes_val.shape)
print(bag_likes_val.shape)
# Out:
# (684,)
# (842,)
# (835,)
# (547,)
# (29,)
# (1517,)
# (1461,)

# %%
all_likes_val = np.concatenate([dress_likes_val, top_likes_val, bottom_likes_val, pullover_likes_val, outerwear_likes_val, shoe_likes_val, bag_likes_val], axis=0)

# %%
# for each outfit get the encodings and create the input and output

dress_index = 0
top_index = 0
bottom_index = 0
pullover_index = 0
outerwear_index = 0
shoe_index = 0
bag_index = 0

outfit_embeddings_list = []
outfit_likes_list = []

for index, row in df_filtered.iterrows():
    outfit_embeddings = []
    for items in row['items']:
        # get the embeddings of all the items from each clothing type
        filename, clothing_type = item['image'], item['category_name']
        
        # for each clothing item maintain different index
        
        # get embeddings according to that index
        
        if clothing_type == 'Dress':
            embedding = dress_data_train[dress_index] 
            dress_index += 1
        elif clothing_type == 'Top':
            embedding = top_data_train[top_index] 
            top_index += 1
        elif clothing_type == 'Bottom':
            embedding = bottom_data_train[bottom_index] 
            bottom_index += 1
        elif clothing_type == 'Pullover':
            
            embedding = pullover_data_train[pullover_index] 
            pullover_index += 1
        elif clothing_type == 'Outerwear':
            embedding = outerwear_data_train[outerwear_index]
            outerwear_index += 1
        elif clothing_type == 'Shoe':
            embedding = shoe_data_train[shoe_index]
            shoe_index += 1
        elif clothing_type == 'Bag':
            embedding = bag_data_train[bag_index]
            bag_index += 1
        else:
            np.zeros((embedding_dimension,))
        
        # if an article is missing put embedding as 0
        # combine all the embeddings in outfit_embeddings
        outfit_embeddings.append(embedding)
        
    # Combine the embeddings for the current outfit and append it to the outfit_embeddings list
    #print(outfit_embeddings)
    combined_embedding = np.concatenate(outfit_embeddings)
    outfit_embeddings_list.append(combined_embedding)

    # Get the likes for the current outfit and append it to the outfit_likes list
    outfit_likes_list.append(row['likes'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-703dc8ee52c5> in <module>
#      16     for items in row['items']:
#      17         # get the embeddings of all the items from each clothing type
# ---> 18         filename, clothing_type = item['image'], item['category_name']
#      19
#      20         # for each clothing item maintain different index
#
# TypeError: string indices must be integers

# %% [markdown]
# # Train a multi-input CNN to predict the likes for each outfit.

# %%
model = Sequential()


# Define the input shapes for each clothing type
dress_input = Input(shape=(32, 32, 3), name='dress_input')
top_input = Input(shape=(32, 32, 3), name='top_input')
bottom_input = Input(shape=(32, 32, 3), name='bottom_input')
pullover_input = Input(shape=(32, 32, 3), name='pullover_input')
outerwear_input = Input(shape=(32, 32, 3), name='outerwear_input')
shoe_input = Input(shape=(32, 32, 3), name='shoe_input')
bag_input = Input(shape=(32, 32, 3), name='bag_input')


# Define the convolutional layers for each clothing type
dress_conv = Conv2D(32, (3, 3), activation='relu')(dress_input)
top_conv = Conv2D(32, (3, 3), activation='relu')(top_input)
bottom_conv = Conv2D(32, (3, 3), activation='relu')(bottom_input)
pullover_conv = Conv2D(32, (3, 3), activation='relu')(pullover_input)
outerwear_conv = Conv2D(32, (3, 3), activation='relu')(outerwear_input)
shoe_conv = Conv2D(32, (3, 3), activation='relu')(shoe_input)
bag_conv = Conv2D(32, (3, 3), activation='relu')(bag_input)

# Flatten the convolutional outputs
dress_flat = Flatten()(dress_conv)
top_flat = Flatten()(top_conv)
bottom_flat = Flatten()(bottom_conv)
pullover_flat = Flatten()(pullover_conv)
outerwear_flat = Flatten()(outerwear_conv)
shoe_flat = Flatten()(shoe_conv)
bag_flat = Flatten()(bag_conv)

# Concatenate the flattened outputs
merged_features = concatenate([dress_flat, top_flat, bottom_flat, pullover_flat, outerwear_flat, shoe_flat, bag_flat])

# Fully connected layers
fc1 = Dense(128, activation='relu')(merged_features)
fc2 = Dense(64, activation='relu')(fc1)
output = Dense(1, activation='linear')(fc2)  # Output layer for likes prediction

# Define the model with multiple inputs and single output
model = Model(inputs=[dress_input, top_input, bottom_input, pullover_input, outerwear_input, shoe_input, bag_input], outputs=output)

# %%
model.compile(optimizer="adam", loss="mean_squared_error")

# %%
model.fit([dress_data_train, top_data_train, bottom_data_train, pullover_data_train, outerwear_data_train, shoe_data_train, bag_data_train], 
          all_likes_train,
          epochs=10, 
          batch_size=32, 
          validation_data=(
              [dress_data_val, top_data_val, bottom_data_val, pullover_data_val, outerwear_data_val, shoe_data_val, bag_data_val],
              all_likes_val,
              )
         )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-251cc8bedd72> in <module>
# ----> 1 model.fit([dress_data_train, top_data_train, bottom_data_train, pullover_data_train, outerwear_data_train, shoe_data_train, bag_data_train],
#       2           all_likes_train,
#       3           epochs=10,
#       4           batch_size=32,
#       5           validation_data=(
#
# ~\Anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# ~\Anaconda3\lib\site-packages\keras\engine\data_adapter.py in _check_data_cardinality(data)
#    1850             )
#    1851         msg += "Make sure all arrays contain the same number of samples."
# -> 1852         raise ValueError(msg)
#    1853
#    1854
#
# ValueError: Data cardinality is ambiguous:
#   x sizes: 2733, 3364, 3338, 2184, 115, 6067, 5842
#   y sizes: 23643
# Make sure all arrays contain the same number of samples.

# %%
# Create a dictionary to map clothing types to their corresponding data and target likes
clothing_data = {
    clothing_type: {
        'data': np.load(embedding_file_path + clothing_type + '_train_embeddings.npy'),
        'likes': np.load(embedding_file_path + clothing_type + '_train_likes.npy')
    } for clothing_type in clothing_list
}
clothing_data
# Out:
# {'Top': {'data': array([[-8.20594258e-04, -7.82323186e-04,  8.73650497e-05, ...,
#            2.56170946e-10, -3.07404519e-11, -6.64314020e-11],
#          [ 5.90826105e-03,  2.70249584e-04, -1.15899194e-03, ...,
#           -3.94650319e-11, -6.58210361e-11, -2.34807052e-11],
#          [-3.20785027e-03,  7.83498283e-04, -8.31825426e-04, ...,
#           -1.10233177e-10, -1.93058611e-10, -1.35758115e-11],
#          ...,
#          [ 1.67688262e-03,  4.49825398e-04, -4.38671821e-04, ...,
#            1.25505245e-10, -3.46517398e-11,  5.40763788e-12],
#          [ 1.85598875e-03, -7.84277159e-04, -4.27327730e-04, ...,
#            1.35156036e-11,  2.15330080e-11, -1.97920881e-11],
#          [ 2.51192716e-04,  6.62153354e-04, -3.39364778e-04, ...,
#            3.01979058e-12,  6.57547697e-11, -1.55233222e-11]], dtype=float32),
#   'likes': array([1071.,   57.,  216., ...,    5.,   93.,   61.])},
#  'Bottom': {'data': array([[-1.12439471e-03,  1.73573862e-04,  1.27199834e-04, ...,
#            2.17156682e-10, -8.58523322e-11,  5.41006649e-11],
#          [-7.28091516e-04,  1.55958231e-04, -1.03890826e-03, ...,
#            9.40313105e-11, -7.42697570e-11,  8.56412163e-12],
#          [ 1.91849051e-03,  4.55904403e-04,  2.84051435e-04, ...,
#            1.15460115e-11,  6.28301994e-11,  2.05871448e-11],
#          ...,
#          [-9.85271879e-04, -5.52150013e-04,  1.62921657e-04, ...,
#           -2.86566899e-11, -1.47553237e-11, -1.76047284e-11],
#          [-1.87804899e-03,  1.76390307e-03,  6.85041479e-04, ...,
#            1.09699375e-10,  1.09964034e-11, -5.72095409e-12],
#          [-6.23041880e-04, -3.10860371e-04, -5.99622399e-05, ...,
#           -3.44645770e-11, -2.19863312e-11, -1.00397572e-11]], dtype=float32),
#   'likes': array([ 921.,  318.,  151., ...,  151.,  348., 1273.])},
#  'Dress': {'data': array([[ 1.52545865e-03, -4.96796492e-05,  7.74612708e-04, ...,
#            1.02639154e-10,  5.82836765e-11,  3.51886090e-11],
#          [ 2.31032536e-04, -4.90159029e-04,  1.23028329e-03, ...,
#           -1.38877895e-10,  1.23077520e-10, -3.25232272e-11],
#          [-2.68553122e-04,  9.46351676e-04,  2.38305118e-04, ...,
#            2.69734485e-10, -2.66953456e-11,  9.15645771e-12],
#          ...,
#          [-1.27571024e-04, -2.00945011e-04,  6.87896390e-04, ...,
#            1.35813140e-11,  2.43853861e-11,  7.50529413e-12],
#          [ 9.67592699e-04, -1.96984591e-04,  5.84574533e-04, ...,
#            4.76290396e-11,  3.62716558e-11, -1.25516143e-11],
#          [ 2.00832309e-03,  2.28602672e-03,  2.88605603e-04, ...,
#           -3.01651724e-11,  2.92528883e-11,  9.71783526e-13]], dtype=float32),
#   'likes': array([418., 353.,  12., ..., 502.,  85., 494.])},
#  'Pullover': {'data': array([[-2.4774841e-03,  6.1632710e-04,  3.6028100e-04, ...,
#           -3.1241896e-07, -1.3800873e-07,  1.8058732e-07],
#          [-2.9646652e-03,  5.2278997e-06,  5.6264648e-04, ...,
#           -2.0406088e-07, -4.5864695e-07, -4.0173099e-08],
#          [-5.2577286e-04, -1.3579446e-04, -5.6723889e-04, ...,
#            8.0854664e-07,  2.5792542e-07, -3.0180183e-07],
#          ...,
#          [ 1.0119376e-03, -9.1241836e-04,  4.5121726e-04, ...,
#           -2.6468308e-07, -1.3487777e-07, -1.3070502e-09],
#          [-2.4611084e-04, -7.3353900e-04, -5.3507194e-04, ...,
#           -2.7188050e-06, -5.9832604e-07, -1.8130020e-06],
#          [ 7.7243528e-04,  2.2793956e-04,  1.3040534e-03, ...,
#            6.0993251e-08,  5.6012698e-08,  1.8681749e-08]], dtype=float32),
#   'likes': array([4.900e+01, 4.840e+02, 5.900e+01, 8.000e+00, 5.310e+02, 3.260e+02,
#          6.000e+00, 7.050e+02, 7.270e+02, 6.700e+01, 2.198e+03, 3.180e+02,
#          1.150e+02, 3.200e+01, 2.880e+03, 4.990e+02, 2.722e+03, 5.860e+02,
#          5.690e+02, 1.050e+02, 3.000e+00, 3.900e+02, 1.095e+03, 5.600e+01,
#          7.850e+02, 7.800e+01, 8.400e+01, 8.000e+00, 2.300e+02, 4.500e+01,
#          9.000e+02, 1.000e+01, 1.040e+02, 5.440e+02, 4.170e+02, 1.410e+02,
#          2.030e+02, 2.310e+02, 9.630e+02, 1.840e+02, 6.270e+02, 1.630e+02,
#          3.700e+01, 1.571e+03, 7.500e+01, 2.278e+03, 4.240e+02, 4.050e+02,
#          1.187e+03, 3.030e+02, 2.680e+02, 1.265e+03, 7.270e+02, 1.253e+03,
#          3.210e+02, 3.000e+00, 5.100e+01, 1.890e+02, 9.700e+01, 3.000e+00,
#          5.600e+01, 1.760e+02, 6.480e+02, 1.171e+03, 2.200e+02, 1.253e+03,
#          2.900e+01, 1.830e+02, 2.330e+02, 4.500e+02, 3.023e+03, 9.220e+02,
#          7.980e+02, 2.700e+01, 7.680e+02, 2.540e+02, 4.420e+02, 1.210e+02,
#          4.500e+01, 4.090e+02, 2.450e+02, 2.300e+01, 8.090e+02, 4.370e+02,
#          4.300e+01, 1.200e+01, 2.190e+02, 1.900e+02, 6.600e+01, 1.810e+02,
#          7.400e+01, 2.250e+02, 2.200e+01, 4.400e+02, 2.000e+02, 1.120e+02,
#          1.195e+03, 4.320e+02, 1.330e+02, 4.640e+02, 1.430e+02, 3.590e+02,
#          1.476e+03, 5.100e+01, 3.300e+01, 3.890e+02, 4.000e+00, 3.640e+02,
#          2.570e+02, 6.000e+00, 1.253e+03, 2.460e+02, 9.000e+00, 1.720e+02,
#          2.190e+02])},
#  'Outerwear': {'data': array([[-6.29758404e-04, -5.07019577e-04, -1.07295484e-04, ...,
#           -7.59524804e-11, -3.37619585e-11,  1.51475655e-11],
#          [-6.31650910e-04,  1.43293073e-04,  5.39405388e-04, ...,
#            1.46611594e-11, -2.94325085e-11, -2.43849428e-12],
#          [-7.40469550e-04, -2.48925819e-04, -4.20612159e-05, ...,
#           -2.15479422e-11,  2.53868940e-11,  3.19467786e-11],
#          ...,
#          [ 1.48238579e-03,  9.49947134e-05,  3.17702856e-04, ...,
#           -4.84184394e-11, -2.76888026e-11, -5.63442218e-12],
#          [-1.06588646e-03, -2.60949659e-04, -2.80270382e-04, ...,
#           -2.62890300e-11,  2.14510736e-11,  6.71834506e-12],
#          [ 1.37216027e-03,  5.77116210e-04, -6.90571789e-04, ...,
#           -3.72313118e-11, -7.26710012e-12, -1.55220056e-11]], dtype=float32),
#   'likes': array([ 50.,  60., 123., ..., 200., 378., 327.])},
#  'Shoe': {'data': array([[ 1.9005587e-03, -2.7879060e-04,  4.4700952e-04, ...,
#            2.0588614e-11,  2.3549060e-12, -8.5118127e-13],
#          [ 3.3596836e-04,  2.7264119e-04,  7.2926749e-04, ...,
#            7.3720439e-12, -2.0726331e-12, -2.0630780e-12],
#          [ 8.4867718e-04,  5.8858184e-04,  7.5923093e-04, ...,
#            1.8252945e-13,  2.9870999e-12,  1.2022245e-13],
#          ...,
#          [-2.6561301e-03,  1.5250313e-03,  7.6998502e-04, ...,
#            4.9791685e-11,  7.3089789e-12,  1.0274131e-11],
#          [-2.5983704e-03,  9.3180430e-04,  3.9199073e-04, ...,
#            1.2441782e-11, -8.6828721e-12,  1.9157779e-12],
#          [-1.5587736e-03, -7.8521791e-04,  7.3458190e-04, ...,
#           -7.3226451e-13, -5.8774977e-12,  1.6360590e-12]], dtype=float32),
#   'likes': array([240., 195.,  64., ...,  54.,   1., 345.])},
#  'Bag': {'data': array([[-5.5086773e-02, -1.5880443e-02,  9.2070028e-03, ...,
#           -3.4542930e-10, -3.0895395e-10,  6.3693734e-10],
#          [ 2.2083392e-02,  4.1535847e-02, -1.4588899e-02, ...,
#            4.5418577e-10, -6.8587971e-09, -8.2276042e-10],
#          [ 1.3220841e-01, -2.0306649e-02,  7.1675284e-03, ...,
#            4.0535495e-09, -3.1836846e-09, -1.0910499e-09],
#          ...,
#          [-8.4052347e-02, -1.8822294e-02,  1.4049655e-02, ...,
#           -1.2541065e-10, -1.8593781e-10, -3.0431824e-10],
#          [-6.9363341e-02, -8.8159125e-03,  2.0344816e-02, ...,
#           -2.5977853e-10, -1.0067020e-10, -8.3459455e-11],
#          [-3.1481024e-02, -1.3371739e-02, -4.8886775e-03, ...,
#            1.5956102e-10,  9.6016639e-11, -3.1911385e-12]], dtype=float32),
#   'likes': array([736.,  90.,  74., ...,   5., 735.,  54.])}}

# %%
def custom_data_generator(batch_size=32):
    while True:
        data_batch, likes_batch = [], []
        for clothing_type in cycle(clothing_list):
            current_data = clothing_data[clothing_type]['data']
            current_likes = clothing_data[clothing_type]['likes']
            available_samples = len(current_data)
            
            if available_samples < batch_size // len(clothing_list):
                # Sample all available samples in the category if they are not enough for the batch size
                indices = np.arange(available_samples)
            else:
                # Randomly sample batch_size // len(clothing_types) samples from the current category with replacement
                indices = np.random.choice(available_samples, batch_size // len(clothing_list), replace=False)
                
            data_batch.extend(current_data[indices])
            likes_batch.extend(current_likes[indices])
            
            if len(data_batch) >= batch_size:
                yield np.array(data_batch[:batch_size]), np.array(likes_batch[:batch_size])
                data_batch, likes_batch = data_batch[batch_size:], likes_batch[batch_size:]

# %%
# Define the number of steps per epoch based on the number of samples in the largest category
batch_size = 1000
max_samples = max(len(clothing_data[clothing_type]['data']) for clothing_type in clothing_list)
steps_per_epoch = max_samples // batch_size

# Fit the model using the custom data generator
model.fit(custom_data_generator(batch_size=batch_size), epochs=10, steps_per_epoch=steps_per_epoch,
          validation_data=(np.array([val_data for _, val_data in clothing_data.values()]),
                           np.array([val_likes for _, val_likes in clothing_data.values()])))
# Out:
# <ipython-input-52-24283214a273>:20: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   yield np.array(data_batch[:batch_size]), np.array(likes_batch[:batch_size])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-0be95c5c5db5> in <module>
#       5
#       6 # Fit the model using the custom data generator
# ----> 7 model.fit(custom_data_generator(batch_size=batch_size), epochs=10, steps_per_epoch=steps_per_epoch,
#       8           validation_data=(np.array([val_data for _, val_data in clothing_data.values()]),
#       9                            np.array([val_likes for _, val_likes in clothing_data.values()])))
#
# ~\Anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\framework\constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#     101       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     102   ctx.ensure_initialized()
# --> 103   return ops.EagerTensor(value, ctx.device_name, dtype)
#     104
#     105
#
# ValueError: Failed to convert a NumPy array to a Tensor (Unsupported object type numpy.ndarray).

# %%
model.predict(
    [dress_data_val, top_data_val, bottom_data_val, pullover_data_val, outerwear_data_val, shoe_data_val, bag_data_val]
)

# %%
#Input end user wardrobe and predict the embedding for each image.
example_url = "user/example"
wardrobe_images = []  # List of wardrobe images

for images in os.listdir(example_url):
    wardrobe_images.add(os.path.join(example_url, images))

# %%
# Predict embedding for each user input wardrobe
preprocessed_images = [prepare_images(image_path) for image_path in wardrobe_images]

dress_embeddings = autoencoders['Dress'].predict(preprocessed_images)
top_embeddings = autoencoders['Top'].predict(preprocessed_images)
bottom_embeddings = autoencoders['Bottom'].predict(preprocessed_images)
pullover_embeddings = autoencoders['Pullover'].predict(preprocessed_images)
outerwear_embeddings = autoencoders['Outerwear'].predict(preprocessed_images)
shoe_embeddings = autoencoders['Shoe'].predict(preprocessed_images)
bag_embeddings = autoencoders['Bag'].predict(preprocessed_images)

# Store the embeddings for further use
embedding_dict = {
    'Dress': dress_embeddings,
    'Top': top_embeddings,
    'Bottom': bottom_embeddings,
    'Pullover': pullover_embeddings,
    'Outerwear': outerwear_embeddings,
    'Shoe': shoe_embeddings,
    'Bag': bag_embeddings
}

# %%
dress_images = ['user/wardrobe/dress1.jpg', 'user/wardrobe/dress2.jpg']
top_images = ['user/wardrobe/top.jpg', 'user/wardrobe/shirt.jpg']  # List of top images
bottom_images = ['user/wardrobe/bottom.jpg', 'user/wardrobe/skirt2.jpg', 'user/wardrobe/skirt1.jpg']  # List of bottom images
shoe_images = ['user/wardrobe/shoee1.jpg']  # List of shoe images
bag_images = ['user/wardrobe/bag1.jpg']  # List of bag images
pullover_images = []  # List of pullover images
outerwear_images = ['user/wardrobe/jacket.jpg']

# %%
#Generate all possible combinations of outfits using the images.
# Define the different types of outfits
outfit_types = [
    ['Top', 'Bottom', 'Shoe', 'Bag'],
    ['Top', 'Bottom', 'Pullover', 'Shoe', 'Bag'],
    ['Top', 'Bottom', 'Outerwear', 'Shoe', 'Bag'],
    ['Top', 'Bottom', 'Pullover', 'Outerwear', 'Shoe', 'Bag'],
    ['Dress', 'Bag', 'Shoe'],
    ['Dress', 'Outerwear', 'Bag', 'Shoe']
]

# Generate all possible combinations of outfits
outfit_combinations = []
for outfit_type in outfit_types:
    items = [top_images, bottom_images, shoe_images, bag_images]
    if 'Pullover' in outfit_type:
        items.append(pullover_images)
    if 'Outerwear' in outfit_type:
        items.append(outerwear_images)
    outfit_combinations.extend(list(itertools.product(*items)))

# %%
# Create a list to store the scores for each outfit
outfit_scores = []

# Iterate through each outfit combination
for combination in outfit_combinations:
    # Create a list to store the images of the outfit
    outfit_images = []

    # Append the images of the outfit to the list
    for image_path in combination:
        # Load or preprocess the image as needed
        prepocessed_image = prepare_image(image_path)

        # Append the image to outfit_images
        outfit_images.append(preprocessed_image)

    # Convert the outfit_images list to a numpy array
    outfit_images = np.array(outfit_images)

    # Make predictions using the CNN model
    outfit_scores.append(model.predict(outfit_images))

# %%
# Print the scores for each outfit
for i, score in enumerate(outfit_scores):
    print(f"Outfit {i+1} score: {score}")
